# %%
# !git clone https://github.com/dremovd/original-translation-books
# Out:
# Cloning into 'original-translation-books'...
# remote: Enumerating objects: 57, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 57 (delta 24), reused 7 (delta 1), pack-reused 0
# Unpacking objects: 100% (57/57), done.
# Checking connectivity... done.

# %%
import pandas as pd

books = pd.read_csv('original-translation-books/russian_original.csv.gz')

# %%
books.sample(20)
# Out:
#           isbn13_rus         isbn13  \
# 11182  9785170541010  9780028639369
# 20060  9785170681631
# 6579   9785170655441  9780505525536
# 19084  9785699837755  9780451192523
# 1036   9785271440571  9781606840603
# 6500   9785171042240  9780192835086
# 7616   9785271398247  9780843951448
# 19239  9785170948208  9780440244042
# 12703  9785170461950  9781568581033
# 2684   9785227040176  9780263886900
# 4322   9785699915286  9782266145978
# 8019   9785170956722  9780451472670
# 22947  9785040957118  9781438009940
# 19457  9785170635085  9780345495037
# 6620   9785040939893  9780316502627
# 19985  9785699528769  9780385339414
# 689    9785227052162  9780373131174
# 15061  9785699833818  9780553562354
# 19319  9785171052546  9780425250921
# 20930  9785699233267  9781566564458
#
#                                          original_title  \
# 11182          The Complete Idiot's Guide to... Drawing
# 20060                                   Room at the Top
# ...
